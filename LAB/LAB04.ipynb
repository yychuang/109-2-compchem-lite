# %% [markdown]
# # Psi4 Lab 04: Introduction
#
# ## Molecular orbitals

# %% [markdown]
# ## Part1
#
# Use B3LYP/6-31+G* to optimize ground state gaseous Benzene __with vibrational frequency calculation to ensure that it is a minimum (i.e. no imaginary frequencies).__  Then perform a single point calculation with optimized structure and extra keywords.

# %%
import psi4

# %%
c6h6 = psi4.geometry("""
0 1
 C                  2.28531853    2.54847650    0.00000000
 C                  3.68047853    2.54847650    0.00000000
 C                  4.37801653    3.75622750    0.00000000
 C                  3.68036253    4.96473650   -0.00119900
 C                  2.28553753    4.96465850   -0.00167800
 C                  1.58793653    3.75645250   -0.00068200
 H                  1.73555953    1.59615950    0.00045000
 H                  4.22998653    1.59596350    0.00131500
 H                  5.47769653    3.75630750    0.00063400
 H                  4.23056253    5.91687950   -0.00125800
 H                  1.73541553    5.91693950   -0.00263100
 H                  0.48833253    3.75663550   -0.00086200
""")

# single point calculation
psi4.set_options({'reference': 'rhf'})
psi4.core.set_output_file('c6h6.log', False)
E, wfn = psi4.energy('b3lyp/6-31+G*', return_wfn=True,molecule=c6h6)

# %%
#find out orbital numbering
# !cat c6h6.log
# Out:
# *** tstart() called on John-A-NB
# *** at Tue May  4 11:32:34 2021
#
#    => Loading Basis Set <=
#
#     Name: 6-31+G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6  entry C          line   119 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#     atoms 7-12 entry H          line    46 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    953 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.697621914100    -1.208026320099     0.000577580602    12.000000000000
#          C            0.697538085900    -1.208026320099     0.000577580602    12.000000000000
#          C            1.395076085900    -0.000275320099     0.000577580602    12.000000000000
#          C            0.697422085900     1.208233679901    -0.000621419398    12.000000000000
#          C           -0.697402914100     1.208155679901    -0.001100419398    12.000000000000
#          C           -1.395003914100    -0.000050320099    -0.000104419398    12.000000000000
#          H           -1.247380914100    -2.160343320099     0.001027580602     1.007825032230
#          H            1.247046085900    -2.160539320099     0.001892580602     1.007825032230
#          H            2.494756085900    -0.000195320099     0.001211580602     1.007825032230
#          H            1.247622085900     2.160376679901    -0.000680419398     1.007825032230
#          H           -1.247524914100     2.160436679901    -0.002053419398     1.007825032230
#          H           -2.494607914100     0.000132679901    -0.000284419398     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.18968  B =      0.18967  C =      0.09484 [cm^-1]
#   Rotational constants: A =   5686.56504  B =   5686.26398  C =   2843.20738 [MHz]
#   Nuclear repulsion =  203.030749007809987
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 42
#   Nalpha       = 21
#   Nbeta        = 21
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 0.00e+00
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31+G*
#     Blend: 6-31+G*
#     Number of shells: 60
#     Number of basis function: 126
#     Number of Cartesian functions: 126
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           FLAT
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         271800
#     Total Blocks           =           2115
#     Max Points             =            256
#     Max Functions          =            126
#
#    => Loading Basis Set <=
#
#     Name: (6-31+G* AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-6  entry C          line   194 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#     atoms 7-12 entry H          line   116 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#
#   ==> Pre-Iterations <==
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    21 ]
#
#   @DF-RKS Final Energy:  -232.25825013960818
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            203.0307490078099875
#     One-Electron Energy =                -713.0982817138276459
#     Two-Electron Energy =                 305.8987250601120991
#     DFT Exchange-Correlation Energy =     -28.0894424937026130
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -232.2582501396082080
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -0.0001      Y:    -0.0001      Z:     0.0010
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -0.0007
#
#   Dipole Moment: [e a0]
#      X:    -0.0000      Y:    -0.0001      Z:     0.0003     Total:     0.0003
#
#   Dipole Moment: [D]
#      X:    -0.0001      Y:    -0.0002      Z:     0.0008     Total:     0.0008
#
#
# *** tstop() called on John-A-NB at Tue May  4 11:32:48 2021
# Module time:
#         user time   =        nan seconds =        nan minutes
#         system time =        nan seconds =        nan minutes
#         total time  =         14 seconds =       0.23 minutes
# Total time:
#         user time   =        nan seconds =        nan minutes
#         system time =        nan seconds =        nan minutes
#         total time  =        681 seconds =      11.35 minutes

# %%
import psi4
# visualize geometry
import fortecubeview

# geometry optimization
e,wfn = psi4.optimize('b3lyp/6-31+G*', return_wfn=True, molecule=c6h6)
print("Optimized Geometry")
print(e)
print(c6h6.to_string(dtype='xyz'))

# perform frequency calculation -- too slow
#psi4.set_options({"normal_modes_write": True})
#e, wfn = psi4.frequency('b3lyp/6-31+G*', molecule=c6h6, return_wfn=True)
# list of frequencies
#freqs = scf_wfn.frequencies().to_array()
#print ("Vibrational Frequencies")
#print(freqs)

# generate orbitals
# [2] Cube files for density (alpha, beta, total, spin) and four orbitals
#     (two alpha, two beta)
# HOMOE no.21
# LUMO  no. 22

psi4.set_options({
    'CUBEPROP_TASKS': ['ESP','ORBITALS','DENSITY'],
    'CUBEPROP_ORBITALS': [21,22],
})
psi4.cubeprop(wfn)
# Out:
# Optimizer: Optimization complete!
# Optimized Geometry
# -232.2588864330331
# 12
# 0 1 C6H6
# C                    -0.699472618086    -1.211332847107     0.000700774079
# C                     0.699342526428    -1.211389796150     0.000561877955
# C                     1.398801354153    -0.000091708662    -0.000022397129
# C                     0.699427033061     1.211359600505    -0.000707531722
# C                    -0.699297536901     1.211415937381    -0.000673193855
# C                    -1.398800994209     0.000038802597     0.000127777845
# H                    -1.243141552414    -2.153023435025     0.001271603059
# H                     1.242909746063    -2.153138923624     0.001080899445
# H                     2.486165156252    -0.000076584355    -0.000035367377
# H                     1.243214010985     2.152982793898    -0.001223880762
# H                    -1.242980164728     2.153099343861    -0.001145843098
# H                    -2.486164391442     0.000156941406     0.000203720062

# %%
# plot orbitals
import fortecubeview
fortecubeview.plot(width=500,height=300,colorscheme='emory',sumlevel=0.75)
# Out:
# CubeViewer: listing cube files from the directory .
# Reading 7 cube files
# c:\programdata\pymol\lib\site-packages\fortecubeview\py3js_renderer.py:1096: FutureWarning: marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
#   values = skimage.measure.marching_cubes_lewiner(data, level * 0.995)
# c:\programdata\pymol\lib\site-packages\fortecubeview\cube_file.py:213: RuntimeWarning: invalid value encountered in double_scalars
#   if partial_sum / sum < fraction:
# VBox(children=(HTML(value=''), Renderer(camera=OrthographicCamera(bottom=-3.0, children=(DirectionalLight(colo…
# HTML(value='\n        <style>\n           .jupyter-widgets-output-area .output_scroll {\n                heigh…
# interactive(children=(Select(description='Cube files:', options=('.\\ESP.cube', 'Density (alpha)', 'Density (b…

# %%
# !rm *.cube

# %% [markdown]
# ## Part2
# Repeat the calculations with substituted benzene with **one electron-donating group (i.e. CH3–, C6H13–, OH–, Cl–, OCH3–, and CHO–)** and **one electron-withdrawing group (i.e. Cl–, CHO–, CN–, NO2–, CF3–, and COOH–).**  Fill the following table and comment your finding.(i.e. what happened to the HOMO/LUMO if we substitute an electron-donating group) *(1 Hartree = 27.21 eV)*

# %% [markdown]
# [eV]	|  Benzene  |     	Toluene  |   	Chlorobenzene
# --------|----------------|--------------|----------------
# HOMO	|      |　　　　　|
# LUMO    |     |          |
# Gap Energy    |       |        |

# %% [markdown]
# ### Toluene

# %%
toluene = psi4.geometry("""
0 1
 C                  0.88642658    0.41551247    0.00000000
 C                  2.28158658    0.41551247    0.00000000
 C                  2.97912458    1.62326347    0.00000000
 C                  2.28147058    2.83177247   -0.00119900
 C                  0.88664558    2.83169447   -0.00167800
 C                  0.18904458    1.62348847   -0.00068200
 H                  0.33666758   -0.53680453    0.00045000
 H                  2.83109458   -0.53700053    0.00131500
 H                  4.07880458    1.62334347    0.00063400
 H                  2.83167058    3.78391547   -0.00125800
 H                 -0.91055942    1.62367147   -0.00086200
 C                  0.11630740    4.16517762   -0.00301249
 H                 -0.81041816    4.04120137   -0.52331012
 H                 -0.07820577    4.46572200    1.00532163
 H                  0.70231141    4.91512013   -0.49197621
""")

# single point calculation
psi4.set_options({'reference': 'rhf'})
psi4.core.set_output_file('toluene.log', False)
E, wfn = psi4.energy('b3lyp/6-31+G*', return_wfn=True,molecule=toluene)

# %%
#find out orbital numbering
# !cat toluene.log
# Out:
# *** tstart() called on John-A-NB
# *** at Tue May  4 12:09:28 2021
#
#    => Loading Basis Set <=
#
#     Name: 6-31+G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 12     entry C          line   119 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#     atoms 7-11, 13-15 entry H          line    46 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    953 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.465902325168    -1.609282269979     0.000962599043    12.000000000000
#          C            0.929257674832    -1.609282269979     0.000962599043    12.000000000000
#          C            1.626795674832    -0.401531269979     0.000962599043    12.000000000000
#          C            0.929141674832     0.806977730021    -0.000236400957    12.000000000000
#          C           -0.465683325168     0.806899730021    -0.000715400957    12.000000000000
#          C           -1.163284325168    -0.401306269979     0.000280599043    12.000000000000
#          H           -1.015661325168    -2.561599269979     0.001412599043     1.007825032230
#          H            1.478765674832    -2.561795269979     0.002277599043     1.007825032230
#          H            2.726475674832    -0.401451269979     0.001596599043     1.007825032230
#          H            1.479341674832     1.759120730021    -0.000295400957     1.007825032230
#          H           -2.262888325168    -0.401123269979     0.000100599043     1.007825032230
#          C           -1.236021505168     2.140382880021    -0.002049890957    12.000000000000
#          H           -2.162747065168     2.016406630021    -0.522347520957     1.007825032230
#          H           -1.430534675168     2.440927260021     1.006284229043     1.007825032230
#          H           -0.650017495168     2.890325390021    -0.491013610957     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.18333  B =      0.08408  C =      0.05825 [cm^-1]
#   Rotational constants: A =   5496.18292  B =   2520.52319  C =   1746.42276 [MHz]
#   Nuclear repulsion =  268.713931495158704
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 50
#   Nalpha       = 25
#   Nbeta        = 25
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 0.00e+00
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31+G*
#     Blend: 6-31+G*
#     Number of shells: 72
#     Number of basis function: 149
#     Number of Cartesian functions: 149
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           FLAT
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         339750
#     Total Blocks           =           2553
#     Max Points             =            256
#     Max Functions          =            148
#
#    => Loading Basis Set <=
#
#     Name: (6-31+G* AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-6, 12     entry C          line   194 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#     atoms 7-11, 13-15 entry H          line   116 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#
#   ==> Pre-Iterations <==
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A        149     149       0       0       0       0
#    -------------------------------------------------------
#     Total     149     149      25      25      25       0
#    -------------------------------------------------------
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.160 GiB; user supplied 0.160 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               163
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.9459
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31+G* AUX)
#     Blend: HEAVY-AUG-CC-PVDZ-JKFIT
#     Number of shells: 268
#     Number of basis function: 907
#     Number of Cartesian functions: 907
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 50.0% of DFT collocation blocks in 0.592 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 5.0684857455E-06.
#   Using Symmetric Orthogonalization.
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF.
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -270.85916435056839   -2.70859e+02   0.00000e+00
#    @DF-RKS iter   1:  -270.88427051784328   -2.51062e-02   7.34104e-03 DIIS
#    @DF-RKS iter   2:  -270.27632972318713    6.07941e-01   1.00699e-02 DIIS
#    @DF-RKS iter   3:  -271.56248601496122   -1.28616e+00   1.02252e-03 DIIS
#    @DF-RKS iter   4:  -271.56563314418645   -3.14713e-03   8.64305e-04 DIIS
#    @DF-RKS iter   5:  -271.57382176131171   -8.18862e-03   2.37615e-04 DIIS
#    @DF-RKS iter   6:  -271.57449416418410   -6.72403e-04   5.40002e-05 DIIS
#    @DF-RKS iter   7:  -271.57452913543466   -3.49713e-05   6.57018e-06 DIIS
#    @DF-RKS iter   8:  -271.57452953978486   -4.04350e-07   3.39394e-06 DIIS
#    @DF-RKS iter   9:  -271.57452966302742   -1.23243e-07   3.49196e-07 DIIS
#    @DF-RKS iter  10:  -271.57452966448864   -1.46122e-09   4.63132e-08 DIIS
#    @DF-RKS iter  11:  -271.57452966450842   -1.97815e-11   1.99245e-08 DIIS
#    @DF-RKS iter  12:  -271.57452966451297   -4.54747e-12   5.60277e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -1.7224      Y:     2.9819      Z:    -0.0019
#
#   Electronic Dipole Moment: [e a0]
#      X:     1.6439      Y:    -2.8481      Z:     0.0141
#
#   Dipole Moment: [e a0]
#      X:    -0.0785      Y:     0.1338      Z:     0.0123     Total:     0.1556
#
#   Dipole Moment: [D]
#      X:    -0.1996      Y:     0.3401      Z:     0.0312     Total:     0.3956
#
#
# *** tstop() called on John-A-NB at Tue May  4 12:10:00 2021
# Module time:
#         user time   =        nan seconds =        nan minutes
#         system time =        nan seconds =        nan minutes
#         total time  =         32 seconds =       0.53 minutes
# Total time:
#         user time   =        nan seconds =        nan minutes
#         system time =        nan seconds =        nan minutes
#         total time  =       2913 seconds =      48.55 minutes

# %%
import psi4
# visualize geometry
import fortecubeview

# geometry optimization
e,wfn = psi4.optimize('b3lyp/6-31+G*', return_wfn=True, molecule=toluene)
print("Optimized Geometry")
print(e)
print(c6h6.to_string(dtype='xyz'))

psi4.set_options({
    'CUBEPROP_TASKS': ['ESP','ORBITALS','DENSITY'],
    'CUBEPROP_ORBITALS': [25,26],
})
psi4.cubeprop(wfn)
# Out:
# Optimizer: Optimization complete!
# Optimized Geometry
# -271.57727765924125
# 12
# 0 1 C6H6
# C                    -0.699472618086    -1.211332847107     0.000700774079
# C                     0.699342526428    -1.211389796150     0.000561877955
# C                     1.398801354153    -0.000091708662    -0.000022397129
# C                     0.699427033061     1.211359600505    -0.000707531722
# C                    -0.699297536901     1.211415937381    -0.000673193855
# C                    -1.398800994209     0.000038802597     0.000127777845
# H                    -1.243141552414    -2.153023435025     0.001271603059
# H                     1.242909746063    -2.153138923624     0.001080899445
# H                     2.486165156252    -0.000076584355    -0.000035367377
# H                     1.243214010985     2.152982793898    -0.001223880762
# H                    -1.242980164728     2.153099343861    -0.001145843098
# H                    -2.486164391442     0.000156941406     0.000203720062

# %%
# plot orbitals
import fortecubeview
fortecubeview.plot(width=500,height=300,colorscheme='emory',sumlevel=0.75)
# Out:
# CubeViewer: listing cube files from the directory .
# Reading 9 cube files
# c:\programdata\pymol\lib\site-packages\fortecubeview\py3js_renderer.py:1096: FutureWarning: marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
#   values = skimage.measure.marching_cubes_lewiner(data, level * 0.995)
# c:\programdata\pymol\lib\site-packages\fortecubeview\cube_file.py:213: RuntimeWarning: invalid value encountered in double_scalars
#   if partial_sum / sum < fraction:
# VBox(children=(HTML(value=''), Renderer(camera=OrthographicCamera(bottom=-3.0, children=(DirectionalLight(colo…
# HTML(value='\n        <style>\n           .jupyter-widgets-output-area .output_scroll {\n                heigh…
# interactive(children=(Select(description='Cube files:', options=('.\\ESP.cube', 'Density (alpha)', 'Density (b…

# %%
# !rm *.cube

# %% [markdown]
# ### Chlorobenzene

# %%
c6h5cl = psi4.geometry("""
0 1
 C                  0.88642658    0.41551247    0.00000000
 C                  2.28158658    0.41551247    0.00000000
 C                  2.97912458    1.62326347    0.00000000
 C                  2.28147058    2.83177247   -0.00119900
 C                  0.88664558    2.83169447   -0.00167800
 C                  0.18904458    1.62348847   -0.00068200
 H                  0.33666758   -0.53680453    0.00045000
 H                  2.83109458   -0.53700053    0.00131500
 H                  4.07880458    1.62334347    0.00063400
 H                  2.83167058    3.78391547   -0.00125800
 H                 -0.91055942    1.62367147   -0.00086200
 Cl                 0.00625909    4.35567521   -0.00320313
""")

# single point calculation
psi4.set_options({'reference': 'rhf'})
psi4.core.set_output_file('c6h5cl.log', False)
E, wfn = psi4.energy('b3lyp/6-31+G*', return_wfn=True,molecule=c6h5cl)

# %%
# !cat c6h5cl.log
# Out:
# *** tstart() called on John-A-NB
# *** at Tue May  4 12:27:35 2021
#
#    => Loading Basis Set <=
#
#     Name: 6-31+G*
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6  entry C          line   119 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#     atoms 7-11 entry H          line    46 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#     atoms 12   entry CL         line   370 file c:\programdata\pymol\lib\share\psi4\basis\6-31pgs.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         1 Threads,    953 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.216261573197    -2.041559213076     0.001378799983    12.000000000000
#          C            1.178898426803    -2.041559213076     0.001378799983    12.000000000000
#          C            1.876436426803    -0.833808213076     0.001378799983    12.000000000000
#          C            1.178782426803     0.374700786924     0.000179799983    12.000000000000
#          C           -0.216042573197     0.374622786924    -0.000299200017    12.000000000000
#          C           -0.913643573197    -0.833583213076     0.000696799983    12.000000000000
#          H           -0.766020573197    -2.993876213076     0.001828799983     1.007825032230
#          H            1.728406426803    -2.994072213076     0.002693799983     1.007825032230
#          H            2.976116426803    -0.833728213076     0.002012799983     1.007825032230
#          H            1.728982426803     1.326843786924     0.000120799983     1.007825032230
#          H           -2.013247573197    -0.833400213076     0.000516799983     1.007825032230
#          CL          -1.096429063197     1.898603526924    -0.001824330017    34.968852682000
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.18968  B =      0.05157  C =      0.04054 [cm^-1]
#   Rotational constants: A =   5686.46946  B =   1545.93081  C =   1215.48701 [MHz]
#   Nuclear repulsion =  313.953700909104327
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 58
#   Nalpha       = 29
#   Nbeta        = 29
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 0.00e+00
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31+G*
#     Blend: 6-31+G*
#     Number of shells: 68
#     Number of basis function: 147
#     Number of Cartesian functions: 147
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: B3LYP <=
#
#     B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch, J. Phys. Chem. 98, 11623 (1994)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.0800   Slater exchange
#     0.7200         Becke 88
#
#    => Exact (HF) Exchange <=
#
#     0.2000               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5_RPA)
#     0.8100   Lee, Yang & Parr
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           FLAT
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         271639
#     Total Blocks           =           2103
#     Max Points             =            256
#     Max Functions          =            143
#
#    => Loading Basis Set <=
#
#     Name: (6-31+G* AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-6  entry C          line   194 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#     atoms 7-11 entry H          line   116 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#     atoms 12   entry CL         line   812 file c:\programdata\pymol\lib\share\psi4\basis\heavy-aug-cc-pvdz-jkfit.gbs
#
#   ==> Pre-Iterations <==
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A        147     147       0       0       0       0
#    -------------------------------------------------------
#     Total     147     147      29      29      29       0
#    -------------------------------------------------------
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.150 GiB; user supplied 0.150 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               153
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       1.9436
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31+G* AUX)
#     Blend: HEAVY-AUG-CC-PVDZ-JKFIT
#     Number of shells: 253
#     Number of basis function: 881
#     Number of Cartesian functions: 881
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.922 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 5.2104851300E-06.
#   Using Symmetric Orthogonalization.
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF.
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  
#      123A      2.096985   124A      2.136117   125A      2.137562
#      126A      2.149345   127A      2.166427   128A      2.281290
#      129A      2.288945   130A      2.309265   131A      2.534409
#      132A      2.578309   133A      2.629822   134A      2.658520
#      135A      2.692032   136A      2.724328   137A      2.724998
#      138A      2.817990   139A      3.011728   140A      3.356795
#      141A      4.198641   142A      4.222602   143A      4.224895
#      144A      4.327814   145A      4.364195   146A      4.401850
#      147A      4.659829
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    29 ]
#
#   @DF-RKS Final Energy:  -691.85414533632013
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            313.9537009091043274
#     One-Electron Energy =               -1569.0013806085980832
#     Two-Electron Energy =                 613.7247647698027322
#     DFT Exchange-Correlation Energy =     -50.5312304066290636
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -691.8541453363201299
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     4.4294      Y:    -7.6706      Z:     0.0084
#
#   Electronic Dipole Moment: [e a0]
#      X:    -4.0623      Y:     7.0348      Z:    -0.0074
#
#   Dipole Moment: [e a0]
#      X:     0.3671      Y:    -0.6358      Z:     0.0010     Total:     0.7342
#
#   Dipole Moment: [D]
#      X:     0.9332      Y:    -1.6160      Z:     0.0024     Total:     1.8661
#
#
# *** tstop() called on John-A-NB at Tue May  4 12:27:59 2021
# Module time:
#         user time   =        nan seconds =        nan minutes
#         system time =        nan seconds =        nan minutes
#         total time  =         24 seconds =       0.40 minutes
# Total time:
#         user time   =        nan seconds =        nan minutes
#         system time =        nan seconds =        nan minutes
#         total time  =       3992 seconds =      66.53 minutes

# %%
import psi4
# visualize geometry
import fortecubeview

# geometry optimization
e,wfn = psi4.optimize('b3lyp/6-31+G*', return_wfn=True, molecule=c6h5cl)
print("Optimized Geometry")
print(e)
print(c6h6.to_string(dtype='xyz'))

psi4.set_options({
    'CUBEPROP_TASKS': ['ESP','ORBITALS','DENSITY'],
    'CUBEPROP_ORBITALS': [29,30],
})
psi4.cubeprop(wfn)
# Out:
# Optimizer: Optimization complete!
# Optimized Geometry
# -691.8549511799331
# 12
# 0 1 C6H6
# C                    -0.699472618086    -1.211332847107     0.000700774079
# C                     0.699342526428    -1.211389796150     0.000561877955
# C                     1.398801354153    -0.000091708662    -0.000022397129
# C                     0.699427033061     1.211359600505    -0.000707531722
# C                    -0.699297536901     1.211415937381    -0.000673193855
# C                    -1.398800994209     0.000038802597     0.000127777845
# H                    -1.243141552414    -2.153023435025     0.001271603059
# H                     1.242909746063    -2.153138923624     0.001080899445
# H                     2.486165156252    -0.000076584355    -0.000035367377
# H                     1.243214010985     2.152982793898    -0.001223880762
# H                    -1.242980164728     2.153099343861    -0.001145843098
# H                    -2.486164391442     0.000156941406     0.000203720062

# %%
# plot orbitals
import fortecubeview
fortecubeview.plot(width=500,height=300,colorscheme='emory',sumlevel=0.75)
# Out:
# CubeViewer: listing cube files from the directory .
# Reading 7 cube files
# VBox(children=(HTML(value=''), Renderer(camera=OrthographicCamera(bottom=-3.0, children=(DirectionalLight(colo…
# HTML(value='\n        <style>\n           .jupyter-widgets-output-area .output_scroll {\n                heigh…
# interactive(children=(Select(description='Cube files:', options=('.\\ESP.cube', 'Density (alpha)', 'Density (b…

# %%
# !rm *.cube
